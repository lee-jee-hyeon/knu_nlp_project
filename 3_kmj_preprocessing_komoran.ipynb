# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import urllib.request
from konlpy.tag import Okt
from tqdm import tqdm
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# # KOMORAN

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
#영화리뷰 데이터 읽어오기
df = pd.read_csv("./data/processed/base_df.csv", encoding='utf-8')

#불용어 읽어오기
stopwords = pd.read_csv("./data/stopwords.txt")
stopwords = stopwords['word'].tolist()

# %%
#불용어제거 + 토큰화
tk = []
for sentence in tqdm(df['review']) :
    tokenized_sentence = komoran.morphs(sentence) # 토큰화
    stopwords_removed_sentence = [word for word in tokenized_sentence if not word in stopwords] # 불용어 제거
    tk.append(stopwords_removed_sentence)
# Out:
# 100%|██████████| 9304/9304 [00:06<00:00, 1366.32it/s]

# %%
tk[:3]
# Out:
# [['판타지',
#   '넘',
#   '영화',
#   '역사',
#   '남',
#   '명작',
#   '다',
#   '내',
#   '이거',
#   'ㄹ',
#   '극장',
#   '못',
#   '보',
#   '았',
#   '을까',
#   '폰',
#   '보',
#   '았',
#   '감동',
#   '비교',
#   '안',
#   '되',
#   'ㄹ텐데'],
#  ['이집트', '여행', '느낌', '영화'],
#  ['목포', '연설', '장면', '넋', '잃', '고', '보', '게', '되', 'ㄴ다']]

# %%
# 정수 인코딩
tokenizer = Tokenizer()
tokenizer.fit_on_texts(tk)

# %%
print(tokenizer.word_counts)
print(tokenizer.word_index)
# Out:
# OrderedDict([('판타지', 37), ('넘', 140), ('영화', 3996), ('역사', 45), ('남', 268), ('명작', 140), ('다', 3549), ('내', 558), ('이거', 72), ('ㄹ', 2525), ('극장', 63), ('못', 159), ('보', 4292), ('았', 3666), ('을까', 112), ('폰', 3), ('감동', 484), ('비교', 32), ('안', 710), ('되', 1488), ('ㄹ텐데', 12), ('이집트', 4), ('여행', 15), ('느낌', 393), ('목포', 1), ('연설', 7), ('장면', 273), ('넋', 2), ('잃', 24), ('고', 4467), ('게', 2801), ('ㄴ다', 612), ('그렇', 224), ('네요', 766), ('뻔하', 145), ('ㄴ', 6996), ('반전', 99), ('결말', 155), ('더 배트맨', 20), ('조커', 35), ('처럼', 120), ('몰입', 242), ('감', 131), ('있', 1742), ('으면', 265), ('추천', 159), ('반대', 10), ('지루', 300), ('면', 636), ('비', 93), ('전', 159), ('올레', 2), ('재밌', 860), ('다가', 208), ('방금', 8), ('소', 16), ('장용', 1), ('재', 273), ('구입', 1), ('어요', 1067), ('는데요', 4), ('부인', 10), ('조여정', 2), ('송승헌', 6), ('섹슈얼한', 1), ('형', 39), ('었', 2958), ('던', 573), ('같', 872), ('아요', 231), ('극', 61), ('중', 278), ('임지연', 6), ('성격', 11), ('이나', 164), ('분위기', 143), ('확', 11), ('다르', 72), ('죠', 89), ('겉', 4), ('조용', 8), ('청순', 1), ('아도', 285), ('은밀', 2), ('과감', 3), ('조용히', 7), ('끼', 25), ('부리', 15), ('ㅂ니다', 830), ('속', 131), ('말', 545), ('호박씨까는스타일이죸', 1), ('그런', 106), ('스타일', 38), ('꽂히', 3), ('수', 804), ('ㄴ듯', 79), ('뭐', 362), ('첫눈', 2), ('반하', 15), ('거', 615), ('준하', 2), ('아서', 800), ('빠지', 92), ('들어가', 62), ('한테', 66), ('꼭', 182), ('대단', 74), ('사랑', 233), ('동기', 6), ('어야만', 8), ('납득', 31), ('가능', 40), ('다고', 285), ('보지', 13), ('않', 769), ('저렇', 21), ('가가', 9), ('포인트', 59), ('라', 378), ('그냥', 381), ('이미', 26), ('좋', 1451), ('많이', 228), ('좋아하', 240), ('니', 208), ('걷', 9), ('버리', 146), ('자체', 127), ('캐릭터', 157), ('감상', 70), ('한', 500), ('러브스토리', 12), ('기반', 12), ('기', 967), ('정사', 2), ('씨', 194), ('군', 18), ('크', 177), ('평범', 48), ('나라', 82), ('가정', 11), ('태어나', 13), ('ㅁ', 1567), ('감사', 74), ('거듭', 2), ('건', 236), ('은데', 122), ('마지막', 231), ('도', 2601), ('에바', 11), ('지', 1923), ('ㅠㅠ', 86), ('영화관', 93), ('잠들', 15), ('유일한', 10), ('생각', 720), ('보다', 432), ('흡입', 9), ('력', 9), ('만', 1044), ('아수라', 7), ('냐', 129), ('이재명', 10), ('주연', 56), ('음주운전', 1), ('주변', 24), ('사람', 408), ('살인', 19), ('위장', 1), ('배우', 744), ('비극', 9), ('없', 1130), ('도록', 16), ('전쟁', 70), ('일어나', 33), ('는데', 1097), ('현재', 18), ('고통', 29), ('받', 180), ('우크라이나', 11), ('생각나', 63), ('에요', 37), ('매력', 136), ('적', 1126), ('특징', 6), ('답', 69), ('스토리', 746), ('개연', 108), ('성', 223), ('마시', 19), ('단순히', 9), ('재미', 242), ('킬링타임', 97), ('하고', 41), ('싶', 434), ('으시', 44), ('다면', 127), ('시', 590), ('조인성', 6), ('연기', 1209), ('커리', 1), ('어의', 2), ('정점', 9), ('다리', 14), ('길', 182), ('어서', 516), ('액션', 374), ('더', 525), ('세련', 6), ('보이', 273), ('초반', 86), ('느와르', 45), ('치고', 18), ('가볍', 78), ('으나', 105), ('중간', 164), ('민호', 1), ('내면', 26), ('면서', 299), ('점점', 29), ('고조', 6), ('눈', 120), ('떼', 28), ('타란티노', 6), ('정통', 2), ('쾌', 2), ('남무', 1), ('미', 67), ('집단', 2), ('계급', 1), ('사회', 54), ('형성', 2), ('따돌림', 2), ('경험', 28), ('공감', 78), ('감정', 127), ('많', 287), ('듯', 407), ('탄탄', 35), ('작가', 31), ('마냥', 18), ('잘', 786), ('쓰', 164), ('발렌타인', 2), ('돌리', 23), ('주', 896), ('ㅅㅅ에', 1), ('미치', 97), ('고추', 2), ('찔리', 1), ('낯', 6), ('뜨겁', 9), ('일부', 8), ('끔찍이', 2), ('싫', 35), ('스럽', 217), ('남자친구', 3), ('고마워요', 4), ('너무', 1170), ('빨리', 31), ('나오', 583), ('망하', 23), ('늦', 14), ('어도', 120), ('흥행', 27), ('텐', 32), ('데', 194), ('ㅜ', 12), ('개띵작데스몬드', 1), ('도스', 3), ('전장', 3), ('가장', 133), ('약하', 32), ('알', 371), ('강하', 29), ('사나이', 4), ('음', 1101), ('지금', 163), ('작품', 278), ('보니', 91), ('망', 46), ('작', 101), ('법', 26), ('자극', 48), ('연속', 13), ('유치', 92), ('문장', 3), ('죄송', 6), ('다시', 262), ('수정', 2), ('러', 102), ('왔는뎈ㅋ이거', 1), ('흠', 11), ('재활용', 1), ('상상', 55), ('자위', 1), ('알리', 31), ('마', 36), ('세', 124), ('요', 329), ('강렬', 20), ('감과', 3), ('파격', 4), ('신선', 91), ('소재', 103), ('오랜만', 133), ('대작', 17), ('관람', 57), ('안녕', 9), ('디지', 5), ('꿈', 27), ('꾸', 8), ('잠', 23), ('ㄹ래', 10), ('친구', 66), ('찾아가', 12), ('탐정', 40), ('물', 120), ('굿', 75), ('재난', 114), ('명맥', 1), ('잇', 32), ('주이', 2), ('이제', 109), ('끝나', 112), ('겠', 406), ('아담스', 2) ...
# {'ㄴ': 1, '고': 2, '보': 3, '영화': 4, '았': 5, '다': 6, '었': 7, '게': 8, '도': 9, 'ㄹ': 10, '지': 11, '있': 12, 'ㅁ': 13, '되': 14, '좋': 15, '연기': 16, '너무': 17, '없': 18, '적': 19, '음': 20, '는데': 21, '어요': 22, '만': 23, '기': 24, '주': 25, '같': 26, '재밌': 27, 'ㅂ니다': 28, '수': 29, '아서': 30, '잘': 31, '않': 32, '네요': 33, '스토리': 34, '배우': 35, '생각': 36, '안': 37, '면': 38, '거': 39, 'ㄴ다': 40, '시': 41, '나오': 42, '던': 43, '진짜': 44, '내': 45, '말': 46, '배트맨': 47, '더': 48, '어서': 49, '만들': 50, '한': 51, '감동': 52, '정말': 53, '싶': 54, '보다': 55, '연출': 56, '사람': 57, '듯': 58, '겠': 59, '느낌': 60, '기대': 61, '그냥': 62, '최고': 63, '라': 64, '액션': 65, '알': 66, '뭐': 67, '감독': 68, '요': 69, '점': 70, 'ㄴ데': 71, '느끼': 72, '지루': 73, '면서': 74, '모르': 75, 'ㄴ가': 76, '번': 77, '많': 78, '아도': 79, '다고': 80, '중': 81, '작품': 82, '내용': 83, '님': 84, '재미있': 85, '장면': 86, '재': 87, '보이': 88, '남': 89, '최민식': 90, '으면': 91, '정도': 92, '다시': 93, '며': 94, '라고': 95, '평점': 96, '못하': 97, '없이': 98, '몰입': 99, '재미': 100, '이야기': 101, '라는': 102, '좋아하': 103, '분': 104, '건': 105, '이렇': 106, '사랑': 107, '아요': 108, '마지막': 109, '많이': 110, '아쉽': 111, '그렇': 112, '다는': 113, '성': 114, '인생': 115, '스럽': 116, '편': 117, '개': 118, '다가': 119, '니': 120, '역시': 121, '수학': 122, '씨': 123, '데': 124, '처음': 125, '두': 126, '현실': 127, '끝': 128, '리': 129, '전개': 130, '꼭': 131, '길': 132, '받': 133, '살': 134, '아깝': 135, '주인공': 136, '크': 137, '대하': 138, '영상미': 139, '마음': 140, '이해': 141, '최악': 142, '괜찮': 143, '서': 144, '이나': 145, '중간': 146, '쓰': 147, '지금': 148, '못': 149, '추천': 150, '전': 151, '캐릭터': 152, '대': 153, '결말': 154, '재미없': 155, 'ㄹ까': 156, '눈물': 157, '버리': 158, '뻔하': 159, '용': 160, '분위기': 161, '별로': 162, '넘': 163, '명작': 164, '돈': 165, '부분': 166, '는지': 167, '매력': 168, '때문': 169, '대사': 170, '다크': 171, '가장': 172, '오랜만': 173, '위하': 174, '감': 175, '속': 176, '개인': 177, '모든': 178, '맞': 179, '믿': 180, '냐': 181, '표현': 182, '연기력': 183, '자체': 184, '다면': 185, '감정': 186, '노': 187, '세': 188, '아름답': 189, '히어로': 190, '인간': 191, '어둡': 192, '랑': 193, '영상': 194, '은데': 195, '어야': 196, '중국': 197, '음악': 198, '처럼': 199, '눈': 200, '어도': 201, '물': 202, 'ㄴ지': 203, '급': 204, '계속': 205, '가족': 206, '울': 207, '재난': 208, '시리즈': 209, '스파이더맨': 210, '을까': 211, '끝나': 212, '모습': 213, '줄': 214, '볼': 215, '이제': 216, '걸': 217, '개연': 218, '시작': 219, '내내': 220, '그런': 221, '특히': 222, '으나': 223, '잔잔': 224, 'ㅋㅋ': 225, '기억': 226, '글': 227, '소재': 228, '죽': 229, '한국': 230, '러': 231, '근데': 232, '달': 233, '작': 234, '힘들': 235, '가슴': 236, '슬프': 237, '가지': 238, '나름': 239, '어떻': 240, '반전': 241, '그것': 242, '암': 243, '필요': 244, '놓': 245, '치': 246, '킬링타임': 247, '미치': 248, '먹': 249, '떨어지': 250, '뿐': 251, '여자': 252, '시키': 253, '한효주': 254, '애': 255, '비': 256, '영화관': 257, '삶': 258, '빠지': 259, '유치': 260, '수준': 261, '훌륭': 262, '아직': 263, '보니': 264, '신선': 265, '긴장감': 266, '배경': 267, '찍': 268, '나이트': 269, '타임': 270, '죠': 271, '낮': 272, '이랑': 273, '라면': 274, '설정': 275, 'ㅠㅠ': 276, '초반': 277, '감성': 278, '이건': 279, '드라마': 280, '원작': 281, '집중': 282, '마블': 283, '따뜻': 284, '입': 285, '나라': 286, '뜨': 287, '여운': 288, '그리': 289, '신': 290, '높': 291, '완전': 292, '깊': 293, '멋지': 294, '실망': 295, '세상': 296, 'ㄴ듯': 297, '상황': 298, '시대': 299, '팬': 300, '매우': 301, '가볍': 302, '공감': 303, '억지': 304, '영화로': 305, '이유': 306, '까': 307, '솔직히': 308, '년대': 309, '완벽': 310, '의미': 311, '그러': 312, '여주': 313, '다니': 314, '니다': 315, '굿': 316, '개봉': 317, '대단': 318, '감사': 319, '빼': 320, '사실': 321, '이거': 322, '다르': 323, '보고': 324, '나가': 325, '금': 326, '풀': 327, '나쁘': 328, '어색': 329, '전혀': 330, '어리': 331, '부족': 332, '호': 333, '별': 334, '후': 335, '롭': 336, '감상': 337, '전쟁': 338, '놀라': 339, '인물': 340, '식': 341, '불': 342, '노래': 343, '답': 344, '빌': 345, '여배우': 346, '트': 347, 'ㄴ다면': 348, '니까': 349, '아주': 350, '웃': 351, '임': 352, '집': 353, '미': 354, '간만': 355, '봄': 356, 'ㄴ다는': 357, '평': 358, '한테': 359, '친구': 360, '새롭': 361, '관객': 362, '시절': 363, '만나': 364, '기분': 365, '찾': 366, '어울리': 367, '제일': 368, '요즘': 369, '무': 370, '인상': 371, 'ㄴ다고': 372, '러닝': 373, '안타깝': 374, '요소': 375, '문제': 376, '마다': 377, '극장': 378, '생각나': 379, '일본': 380, '들어가': 381, '늘': 382 ...

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 12349
# 등장 빈도가 2번 이하인 희귀 단어의 수: 7904
# 단어 집합에서 희귀 단어의 비율: 64.00518260587901
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 5.481672771950581

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 4446

# %%
#텍스트 시퀀스 >> 정수 시퀀스
tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(tk)
tk = tokenizer.texts_to_sequences(tk)
print(tk[:3])
# Out:
# [[598, 163, 4, 503, 89, 164, 6, 45, 322, 10, 378, 149, 3, 5, 211, 3521, 3, 5, 52, 681, 37, 14, 1407], [2944, 1209, 60, 4], [2076, 86, 855, 2, 3, 8, 14, 40]]

# %%
#target data 따로 지정
yy = np.array(df['sentiment'])

# %%
# 빈 샘플 제거
drop_index = [index for index, sentence in enumerate(tk) if len(sentence) < 1]
len(drop_index)
# Out:
# 52

# %%
tk = np.delete(tk, drop_index, axis=0)
yy = np.delete(yy, drop_index, axis=0)
print(len(tk))
print(len(yy))
# Out:
# 9252
# 9252
# C:\Users\kdh\miniconda3\envs\nlp\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
#패딩
print('리뷰의 최대 길이 :',max(len(review) for review in tk))
print('리뷰의 평균 길이 :',sum(map(len, tk))/len(tk))
plt.hist([len(review) for review in tk], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 334
# 리뷰의 평균 길이 : 17.96011673151751

# %%
plt.hist([len(review) for review in tk], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.xlim(0, 100)
plt.show()

# %% [markdown]
# max_len 50으로 결정

# %%
def below_threshold_len(max_len, nested_list):
  count = 0
  for sentence in nested_list:
    if(len(sentence) <= max_len):
        count = count + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (count / len(nested_list))*100))

max_len = 50
below_threshold_len(max_len, tk)
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 94.74708171206225

# %%
final = pad_sequences(tk, maxlen=max_len)

# %%
final_ = list(map(lambda x:[x],final.astype(object)))

# %%
final_df = pd.DataFrame(final_,columns=['word'])
y_df = pd.DataFrame(yy)

# %%
final_df = pd.concat([final_df, y_df], axis=1)
final_df.columns = ['word','label']

# %%
final_df.to_csv('./data/processed/komoran_df.csv')
